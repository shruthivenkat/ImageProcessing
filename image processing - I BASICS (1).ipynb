# %%
from matplotlib import pyplot as plt
import matplotlib.cm as cm

# %%
from skimage import data

# %%
from skimage.feature import blob_dog, blob_log, blob_doh
from math import sqrt

import glob
from skimage.io import imread

# %%
spot_img = glob.glob(r"C:\Users\pc-pc\Documents\Datasets_for_practise\two.png")[0]
im = imread(spot_img, as_grey=True)  #importing the data as a grey scale image
plt.imshow(im, cmap=cm.gray)
plt.show()

# %%
blobs_log = blob_log(im, max_sigma=30, num_sigma=10, threshold=0.3) #blobs_log -> x-coord, y-coord, radius of the bright image in terms of pixels
print(blobs_log)

# blobs_log[:, 2] = blobs_log[:, 2] * sqrt(2)
# print(blobs_log)

nums = len(blobs_log)
print("Number of stars counted : " ,nums)
# Out:
# [[116.         158.           4.22222222]
#  [116.         136.           4.22222222]]
# Number of stars counted :  2

# %%
fig, ax = plt.subplots(1, 1)
plt.imshow(im, cmap=cm.gray)
for blob in blobs_log:
    y, x, r = blob
    c = plt.Circle((x, y), r+5, color='yellow', linewidth=2, fill=False)
    ax.add_patch(c)

# %%
spot_img = glob.glob(r"C:\Users\pc-pc\Documents\Datasets_for_practise\three.jpg")[0]
im = imread(spot_img, as_grey=True)
plt.imshow(im, cmap=cm.gray)
plt.show()

# %%
blobs_log = blob_log(im, max_sigma=30, num_sigma=10, threshold=0.1)
print(blobs_log)

blobs_log[:, 2] = blobs_log[:, 2] * sqrt(2)
print(blobs_log)

nums = len(blobs_log)
print("Number of stars counted : " ,nums)
# Out:
# [[239. 286.  30.]
#  [238. 566.  30.]
#  [238. 428.  30.]]
# [[239.         286.          42.42640687]
#  [238.         566.          42.42640687]
#  [238.         428.          42.42640687]]
# Number of stars counted :  3

# %%
fig, ax = plt.subplots(1, 1)
plt.imshow(im, cmap=cm.gray)
for blob in blobs_log:
    y, x, r = blob
    c = plt.Circle((x, y), r+5, color='yellow', linewidth=2, fill=False)
    ax.add_patch(c)

# %%
spot_img = glob.glob(r"C:\Users\pc-pc\Documents\Datasets_for_practise\A1rL6udG2dL._SY606_.jpg")[0]
im = imread(spot_img, as_grey=True)
plt.imshow(im, cmap=cm.gray)
plt.show()

# %%
blobs_log = blob_log(im, max_sigma=30, num_sigma=10, threshold=0.1)
print(blobs_log)

blobs_log[:, 2] = blobs_log[:, 2] * sqrt(2)
print(blobs_log)

nums = len(blobs_log)
print("Number of stars counted : " ,nums)
# Out:
# [[605. 347.   1.]
#  [605. 311.   1.]
#  [605. 309.   1.]
#  ...
#  [  0. 153.   1.]
#  [  0. 122.   1.]
#  [  0. 101.   1.]]
# [[605.         347.           1.41421356]
#  [605.         311.           1.41421356]
#  [605.         309.           1.41421356]
#  ...
#  [  0.         153.           1.41421356]
#  [  0.         122.           1.41421356]
#  [  0.         101.           1.41421356]]
# Number of stars counted :  2538

# %%
fig, ax = plt.subplots(1, 1)
plt.imshow(im, cmap=cm.gray)
for blob in blobs_log:
    y, x, r = blob
    c = plt.Circle((x, y), r+5, color='yellow', linewidth=2, fill=False)
    ax.add_patch(c)
